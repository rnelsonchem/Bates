# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('savefig', dpi=100)

# %%
datafile = open('static/MnO.csv')
n = 0
for line in datafile:
    if n == 10: break
    print line,
    n += 1
# Out:
# Query, Refcode,DIST1
# 3,ADPORF,2.118
# 3,NBNTLF,2.134
# 3,TZAXKA,2.117
# 3,XVPDLV,2.128
# 3,EPSWMM,2.139
# 3,CESKUG,2.106
# 3,UZYUFF,2.110
# 3,ORVDFZ,2.289
# 3,EIXBTX,2.200

# %%
data = np.genfromtxt('static/MnO.csv', skip_header=1, delimiter=',', usecols=2)

# %%
plt.hist(data, bins=50)

plt.grid()
plt.ylabel('Frequency', fontsize=15)
plt.ylim(ymin=-50)
plt.xlabel(u'Mn-O Distance (\u00c5)', fontsize=15)
